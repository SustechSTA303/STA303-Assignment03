# %%
import matplotlib.pyplot as plt

algorithm = ["A* Euler","A* Manhatten","A* Chebyshev","BFS","Dijkstra","Greeedy BestFS"]
count = [120848,176748,137676,178625,178499,173440]
time = [1.171216,1.999215,1.196673,0.218904,1.375788,1.463729]

plt.bar(algorithm,count)
plt.xlabel("Algorithm")
plt.ylabel("Total iterations")
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(algorithm,time)
plt.xlabel("Algorithm")
plt.ylabel("Total time")
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
